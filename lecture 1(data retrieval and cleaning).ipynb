# %% [markdown]
# # QSAR Bootcamp – Lecture 1
# ## Bioactivity Data Collection & Curation using ChEMBL
#
# ---
#
# ## How to Use This Notebook
#
#
# Each code cell is **preceded by an explanation** so that:
# - You understand *why* we are running the code
# - You understand *what* the code is doing
# - You can confidently reproduce this workflow later
#
# ⚠️ Important:
# This lecture focuses **only on bioactivity data collection and preparation**.

# %% [markdown]
# ## What is QSAR?
#
# QSAR stands for **Quantitative Structure–Activity Relationship**.
#
# In simple words:
# > QSAR tries to learn the relationship between a molecule’s **chemical structure**
# and its **biological activity** using data and mathematics.
#
# Instead of experimentally testing thousands of compounds in the lab,
# QSAR allows us to:
# - Test a smaller number of compounds experimentally
# - Learn patterns from this data
# - Predict activity of new compounds computationally
#
# This approach saves **time, cost, and experimental effort** in drug discovery.

# %% [markdown]
# ## Introduction to the ChEMBL Database
#
# ChEMBL is a **manually curated database** maintained by EMBL-EBI.
# It contains:
#
# - Chemical structures of small molecules
# - Biological targets such as enzymes and receptors
# - Experimentally measured bioactivity data such as IC50, EC50, Ki, and Kd
#
#
# **Experimentally measured bioactivity data** are numbers obtained from lab experiments that tell us **how strongly a molecule (drug/compound) interacts with a biological target** (like a protein or enzyme).
#
# ### Common types:
#
# ### **1. IC₅₀ (Inhibitory Concentration 50%)**
#
# * The concentration of a compound needed to **reduce the activity of a protein by 50%**.
# * **Lower IC₅₀ = stronger inhibitor**
# * Example:
#   If Drug A has IC₅₀ = 5 µM and Drug B has IC₅₀ = 50 µM → **Drug A is more potent**
#
# ---
#
# ### **2. EC₅₀ (Effective Concentration 50%)**
#
# * The concentration of a compound needed to produce **50% of its maximum biological effect**.
# * Used when a compound **activates** a receptor.
# * **Lower EC₅₀ = stronger effect**
#
# ---
#
# ### **3. Ki (Inhibition Constant)**
#
# * Measures how tightly an inhibitor binds to an enzyme.
# * **Lower Ki = stronger binding**
# * More “pure” binding measure, less dependent on experimental conditions.
#
# ---
#
# ### **4. Kd (Dissociation Constant)**
#
# * Measures how tightly **any ligand binds to a target**.
# * **Lower Kd = tighter binding**
# * Example:
#   Low Kd means the ligand **does not easily fall off** the protein.
#
# ---
#
# ### **In one line (easy to remember):**
#
# * **IC₅₀ / EC₅₀ → how much drug is needed**
# * **Ki / Kd → how strongly the drug binds**
# * **Lower value = better/stronger interaction**
#
#
#
# Why ChEMBL is important for QSAR:
# - Data is derived from **wet-lab experiments**
# - Targets are well annotated
# - Units are standardized
#
# In QSAR modeling, ChEMBL is one of the **most trusted public data sources**.

# %% [markdown]
# First we need to connect **Google Colab with our Google Drive**, so that we can have access to our Google drive within Colab.
#
# This allows us to:
#
# Save datasets
# Reload data across sessions
# Organize project files

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)

# %% [markdown]
# Now create "data" folder in our "Colab Notebooks" folder on Google Drive

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %% [markdown]
# ## Installing Required Libraries
#
# Before we start, we need to install the Python library that allows us to
# communicate with the ChEMBL database.
#
# We do this using `pip`, which is Python’s package manager.
#
# **We install the ChEMBL web service package so that we can retrieve bioactivity data**

# %%
# !pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Importing Python Libraries
#
# Now we import the required libraries:
#
# - `pandas`: used to handle tabular data (similar to Excel)
# - `chembl_webresource_client`: used to access ChEMBL data

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Search for Target
# In QSAR, bioactivity data is always associated with a **specific biological target**.
#
# In this bootcamp, we use **4EY7**:
#
# ChEMBL ID for this target: **CHEMBL220**

# %%
target = new_client.target
target_query = target.search("4EY7")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism                     pref_name  score  \
# 0               []  Homo sapiens          Acetylcholinesterase   12.0
# 1               []  Homo sapiens  Cholinesterases; ACHE & BCHE    8.0
#
#    species_group_flag target_chembl_id  \
# 0               False        CHEMBL220
# 1               False    CHEMBL2095233
#
#                                    target_components        target_type  \
# 0  [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
#
#    tax_id
# 0    9606
# 1    9606

# %% [markdown]
# **Reterive Bioactivity data for selected target**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# **# Understanding IC50 Bioactivity Data**
#
# IC50 stands for Inhibitory Concentration 50%.
#
# It is the concentration of a compound required to inhibit 50% of the biological activity of a target.
#
# Key points:
#
# Lower IC50 → stronger inhibitor
# Higher IC50 → weaker inhibitor
# IC50 values are usually measured in nanomolar (nM)
# IC50 is one of the most commonly used endpoints in QSAR modeling

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        33969                  []
# 1        None             None        37563                  []
# 2        None             None        37565                  []
# 3        None             None        38902                  []
# 4        None             None        41170                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4    CHEMBL643384  Inhibitory concentration against acetylcholine...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# ...

# %% [markdown]
# # **Initial Exploration of the Dataset**
#
# Before cleaning the data, it is important to understand:
# - How many data points we have
# - The range of IC50 values
#
# This gives us a sense of dataset quality.

# %%
print("Total records:", df1.shape[0])
df1['standard_value'].describe()
# Out:
# Total records: 10079
# count        8793
# unique       3549
# top       10000.0
# freq          277
# Name: standard_value, dtype: object

# %% [markdown]
# # **Data Cleaning – Why It Is Necessary**
#
# Machine learning models are very sensitive to bad data.
#
# We must remove:
#
# Compounds with missing IC50 values
# Compounds with missing chemical structures (SMILES)
# Duplicate molecules
# Clean data leads to reliable QSAR models.

# %%
df = df1[df1.standard_value.notna()]
df = df[df.canonical_smiles.notna()]
df = df.drop_duplicates(['canonical_smiles'])

print("Records after cleaning:", df.shape[0])
# Out:
# Records after cleaning: 7175

# %% [markdown]
# # **Labeling Compounds Based on Activity**
#
# For classification-based QSAR models, we convert continuous IC50 values into activity classes.
#
# Thresholds used:
#
# Active: IC50 ≤ 1000 nM
# Inactive: IC50 ≥ 10000 nM
# Intermediate: values in between
# These thresholds are biologically motivated and commonly used.

# %%
def label_activity(x):
    if x <= 1000:
        return 'active'
    elif x >= 10000:
        return 'inactive'
    else:
        return 'intermediate'

df['class'] = df.standard_value.astype(float).apply(label_activity)
df[['molecule_chembl_id', 'standard_value', 'class']].head()
# Out:
#   molecule_chembl_id standard_value     class
# 0       CHEMBL133897          750.0    active
# 1       CHEMBL336398          100.0    active
# 2       CHEMBL131588        50000.0  inactive
# 3       CHEMBL130628          300.0    active
# 4       CHEMBL130478          800.0    active

# %% [markdown]
# # **Saving the Curated QSAR Dataset**
#
# Finally, we save the cleaned and labeled dataset.
#
# This dataset will be used in the next lecture to calculate molecular descriptors and build QSAR models.

# %%
from google.colab import files

df_final = df[['molecule_chembl_id', 'canonical_smiles', 'standard_value', 'class']]
df_final.to_csv('bioactivity_curated.csv', index=False)
df_final.head()

# Download Excel file
files.download("bioactivity_curated.csv")

# %% [markdown]
# ## Lecture Summary
#
# In this lecture, we:
# - Introduced QSAR modeling
# - Learned about the ChEMBL database
# - Retrieved real experimental IC50 data
# - Cleaned and curated the dataset
# - Prepared data for downstream QSAR modeling
